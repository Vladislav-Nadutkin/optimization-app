# %%
import cianparser

# %%
import pandas as pd

# %%
parser = cianparser.CianParser(location="Мурино")
data = parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":1, "end_page":5})
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\Евгений\Documents\Вкусвилл\cian_flat_sale_1_5_murino_10_Aug_2024_00_23_41_791910.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=flat&room1=1&room2=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 20 %. Average price: 207 517 706 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 56. Progress ratio: 40 %. Average price: 229 843 432 rub
#  3 | 3 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 84. Progress ratio: 60 %. Average price: 235 939 016 rub
# ...

# %%
spb_parser=cianparser.CianParser(location="Санкт-Петербург")

# %%
for i in range(1, 40):
    data4 = spb_parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":86+i, "end_page":86+i})
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\Евгений\Documents\Вкусвилл\cian_flat_sale_87_87_sankt-peterburg_07_Aug_2024_16_40_23_022627.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=87&with_neighbors=0&region=2&deal_type=sale&offer_type=flat&room1=1&room2=1
#
# ...
#  1 | 87 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 47 957 137 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\Евгений\Documents\Вкусвилл\cian_flat_sale_88_88_sankt-peterburg_07_Aug_2024_16_40_31_951931.csv
#
# The page from which the collection of information begins:
# ...

# %%
data3
# Out:
# [{'author': 'Алькор',
#   'author_type': 'developer',
#   'url': 'https://spb.cian.ru/sale/flat/305190388/',
#   'location': 'Санкт-Петербург',
#   'deal_type': 'sale',
#   'accommodation_type': 'flat',
#   'floor': 3,
#   'floors_count': 5,
#   'rooms_count': 1,
#   'total_meters': 34.54,
#   'price': 11542073,
#   'district': 'Кронштадтский',
#   'street': 'дорога Цитадельская',
#   'house_number': '',
#   'underground': 'Беговая',
#   'residential_complex': 'Кронфорт.Центральный'},
#  {'author': 'Школа Недвижимости',
#   'author_type': 'real_estate_agent',
#   'url': 'https://spb.cian.ru/sale/flat/300145447/',
#   'location': 'Санкт-Петербург',
#   'deal_type': 'sale',
#   'accommodation_type': 'flat',
#   'floor': 4,
#   'floors_count': 10,
#   'rooms_count': 1,
#   'total_meters': 45.0,
#   'price': 9350000,
#   'district': 'Василеостровский',
#   'street': ' Кораблестроителей',
#   'house_number': '22К1',
#   'underground': 'Приморская',
#   'residential_complex': ''},
# ...

# %%
pd.DataFrame.from_dict(data3)
# Out:
#                               author        author_type  \
# 0                             Алькор          developer
# 1                 Школа Недвижимости  real_estate_agent
# 2                                RBI          developer
# 3                               VALO  real_estate_agent
# 4                             Алькор          developer
# 5                        Golden Home  real_estate_agent
# 6                                RBI          developer
# 7                        Golden Home  real_estate_agent
# 8          Главстрой Санкт-Петербург          developer
# 9           Brokers Pro Недвижимость  real_estate_agent
# 10                            GloraX          developer
# 11                      ID 115040719          homeowner
# 12         Главстрой Санкт-Петербург          developer
# 13                         Вам к нам  real_estate_agent
# 14                               ПИК          developer
# 15                   MARINOVA estate  real_estate_agent
# ...

# %%
data2 = spb_parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":, "end_page":})

# %%
pd.DataFrame.from_dict(data_sale).to_csv('data_sale.csv')

# %%
pd.DataFrame.from_dict(data_sale2).to_csv('data_sale2.csv')

# %%
data_sale3 = cianparser.parse(location="Санкт-Петербург", deal_type="rent_long", accommodation_type="flat", rooms=(1, 2), start_page=43, end_page=100)

# %%
    
data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location="Краснодар",
    rooms=('studio', 1, 2),
    start_page=40,
    end_page=100,
    is_saving_csv=True
)

print(data[0])
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# /home/netbug/fiddle/K0t1k/cian_parsing_result_sale_40_100_krasnodar_07_Dec_2023_11_32_51_749908.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=40&region=4820&offer_type=flat&deal_type=sale&room9=1&room1=1&room2=1&with_neighbors=0
# 40 page: there is CAPTCHA... failed to parse page...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 0. Average price: 0 rub
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 13
#       1 import cianparser
#       3 data = cianparser.parse(
#       4     deal_type="sale",
#       5     accommodation_type="flat",
#    (...)
#      10     is_saving_csv=True,
#      11 )
# ...

# %%
len(data)
# Out:
# 56

# %%
import cianparser

proxies = ['localhost:12000']

data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location="Москва",
    rooms=('studio', 1, 2),
    start_page=1,
    end_page=2,
    is_saving_csv=False,
    proxies=proxies
)

print(data[0])
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&region=1&offer_type=flat&deal_type=sale&room9=1&room1=1&room2=1&with_neighbors=0
# 1 page: there is CAPTCHA... failed to parse page...
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parsed announcements: 0. Average price: 0 rub
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 16
#       3 proxies = ['localhost:12000']
#       5 data = cianparser.parse(
#       6     deal_type="sale",
#       7     accommodation_type="flat",
#    (...)
#      13     # proxies=proxies
#      14 )
# ---> 16 print(data[0])
#
# IndexError: list index out of range

# %%
from cianparser.helpers import is_available_proxy

is_available_proxy("https://ifconfig.me/all", ["31.186.136.15:3128"])
# Out:
# Response: ip_addr: 185.159.81.136
# remote_host: unavailable
# user_agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:120.0) Gecko/20100101 Firefox/120.0
# port: 48848
# language:
# referer:
# connection:
# keep_alive:
# method: GET
# encoding: identity
# mime:
# charset:
# via: 1.1 google
# forwarded: 185.159.81.136,34.117.118.44
#
# Proxy OK!
# (True, False)

# %%
from cianparser.helpers import is_available_proxy
is_available_proxy("https://cian.ru/cat.php?engine_version=2&p=1&region=1&offer_type=flat&deal_type=sale&room9=1&room1=1&room2=1&with_neighbors=0", ["localhost:12000"])
# Out:
# Response:
#
#
# Captcha - база объявлений ЦИАН
# (False, True)

# %%
5.228.183.207:8080
213.184.153.66:8080
192.162.192.148:55443
178.140.177.145:8889
95.66.138.21:8880
195.128.96.213:8080
93.157.248.108:88
176.99.2.43:1081
188.43.228.25:8080
109.194.22.61:8080
31.186.136.15:3128
194.124.37.9:8080
91.235.220.122:80
193.233.203.58:3128
5.165.6.188:1513
91.197.77.118:443
46.160.209.155:8088
188.127.249.9:20255
95.71.125.50:49882
188.235.0.207:8282
